# %%
#import liberies and create dataframe
import pandas as pd
import numpy as np 
import matplotlib as plt
df = pd.read_excel('/Users/husaindabaja/Downloads/tabn303.10.xlsx')

# %%
df.head(25)
# Out:
#    Table 303.10. Total fall enrollment in degree-granting postsecondary institutions, by attendance status, sex of student, and \n              control of institution: Selected years, 1947 through 2031  \
# 0                                                Year
# 1                                                Year
# 2                                                Year
# 3                                                   1
# 4                                             1947\1\
# 5                                             1948\1\
# 6                                             1949\1\
# 7                                             1950\1\
# 8                                             1951\1\
# 9                                             1952\1\
# 10                                            1953\1\
# 11                                            1954\1\
# 12                                            1955\1\
# 13                                            1956\1\
# ...

# %%
#convert attendence for male and female columuns into a list
list_of_females = df['Unnamed: 7'].to_list()
list_of_males = df['Unnamed: 6'].to_list()

# %%
start_year = 1947
end_year = 2021

# Create an array of years using numpy's arange function
years = np.arange(start_year, end_year + 1)
print(list_of_males)
# Out:
# ['Sex of student', 'Male', 'Male', 6, 1659249, 1709367, 1721572, 1560392, 1390740, 1380357, 1422598, 1563382, 1733184, 1911458, 2170765, 2332617, 2585821, 2961540, 3248713, 3630020, 3856216, 4132800, 4477649, 4746201, 5043642, 5207004, 5238757, 5371052, 5622429, 6148997, 5810828, 5789016, 5640998, 5682877, 5874374, 5975056, 6031384, 6023725, 5863574, 5818450, 5884515, 5932056, 6001896, 6190015, 6283909, 6501844, 6523989, 6427450, 6371898, 6342539, 6352825, 6396028, 6369265, 6515164, 6721769, 6960815, 7202116, 7260264, 7387262, 7455925, 7572265, 7819938, 8177714, 8732953, 9045759, 9034256, 8919006, 8861197, 8797530, 8723819, 8638422, 8571314, 8444614, 8363889, 7885033, 7769476, 7814376, 7793420, 7938395, 8093082, 8209834, 8290887, 8348686, 8382570, 8405071, 8439309, nan, nan, nan, nan, nan, nan, nan, nan]

# %%
#convert list to array
females = np.array(list_of_females)
males = np.array(list_of_males)

# %%
# Sample data (replace with your actual data)
years = np.array([1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021])
males = np.array([1659249,1709367,1721572,1560392,1390740,1380357,1422598,1563382,1733184,1911458,2170765,2332617,2585821,2961540,3248713,3630020,3856216,4132800,4477649,4746201,5043642,5207004,5238757,5371052,5622429,6148997,5810828,5789016,5640998,5682877,5874374,5975056,6031384,6023725,5863574,5818450,5884515,5932056,6001896,6190015,6283909,6501844,6523989,6427450,6371898,6342539,6352825,6396028,6369265,6515164,6721769,6960815,7202116,7260264,7387262,7455925,7572265,7819938,8177714,8732953,9045759,9034256,8919006,8861197,8797530,8723819,8638422,8571314,8444614,8363889,7885033,7769476,7814376,7793420,7938395])
females = np.array([678977,694029,723328,720906,711222,753885,808456,883311,919850,1006754,1153018,1307230,1559244,1818069,2031307,2290844,2533656,2778948,3035442,3258459,3537245,3741640,3976103,4231071,4601300,5035862,5201309,5496771,5619094,5887022,6222521,6396616,6394396,6440936,6378366,6428605,6618996,6834586,7053441,7348545,7534728,7857109,7963370,7877353,7906892,7919242,8014695,8106306,8137702,8334527,8590520,8967172,9409595,9651217,9884782,10031550,10181965,10438200,10903972,11580641,11973679,11976334,11725472,11515480,11411562,11264385,11208482,11206837,11206798,11266289,11142377,10890375,11146905,11146149,11309244])

# Create line graph for male and female students
plt.plot(years, males, label='Male Students', marker='o')
plt.plot(years, females, label='Female Students', marker='o')

# Add labels and title
plt.title('Student Enrollment Over Years')
plt.xlabel('Year')
plt.ylabel('Number of Students')
plt.yticks(np.linspace(678977, 11794467, num=5))  # Adjust the number of ticks as needed
# Add legend
plt.legend()

# Display the graph
plt.grid(True)
plt.show()
